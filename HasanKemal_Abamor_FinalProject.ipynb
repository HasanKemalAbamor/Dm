# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
Df=pd.read_csv('/Users/hasankemalabamor/Downloads/archive/arabica_data_cleaned.csv')

# %%
Df.shape
# Out:
# (1311, 44)

# %%
Df.isnull()
Df = Df.dropna(axis=0, subset=['Country.of.Origin'])

# %%
Df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       7
# Country.of.Origin           0
# Farm.Name                 355
# Lot.Number               1040
# Mill                      309
# ICO.Number                146
# Company                   208
# Altitude                  222
# Region                     56
# Producer                  229
# Number.of.Bags              0
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               46
# Grading.Date                0
# Owner.1                     7
# Variety                   200
# Processing.Method         151
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(Df)

# %%
Df.corr()
# Out:
#                       Unnamed: 0  Number.of.Bags     Aroma    Flavor  \
# Unnamed: 0              1.000000       -0.069985 -0.627560 -0.731404
# Number.of.Bags         -0.069985        1.000000 -0.013084 -0.008531
# Aroma                  -0.627560       -0.013084  1.000000  0.813734
# Flavor                 -0.731404       -0.008531  0.813734  1.000000
# Aftertaste             -0.728466       -0.012212  0.776508  0.894965
# Acidity                -0.648451        0.021148  0.724025  0.816210
# Body                   -0.593066        0.014008  0.697686  0.763022
# Balance                -0.686870        0.019309  0.718161  0.803618
# Uniformity             -0.331094        0.021577  0.366969  0.409810
# Clean.Cup              -0.309086        0.028315  0.335770  0.396746
# Sweetness              -0.202485        0.007166  0.328387  0.362321
# Cupper.Points          -0.708814       -0.013184  0.693798  0.797496
# Total.Cup.Points       -0.691670        0.011115  0.797582  0.878209
# ...

# %%
Df.plot(kind='scatter',x='Total.Cup.Points',y='Aftertaste')
plt.show()

# %%
Df['Color']=Df['Color'].astype('category').cat.codes
Df['Harvest.Year']=Df['Harvest.Year'].astype('category').cat.codes

# %%
Df.corr()
# Out:
#                       Unnamed: 0  Number.of.Bags  Harvest.Year     Aroma  \
# Unnamed: 0              1.000000       -0.069985     -0.059588 -0.627560
# Number.of.Bags         -0.069985        1.000000      0.161597 -0.013084
# Harvest.Year           -0.059588        0.161597      1.000000  0.021979
# Aroma                  -0.627560       -0.013084      0.021979  1.000000
# Flavor                 -0.731404       -0.008531      0.036446  0.813734
# Aftertaste             -0.728466       -0.012212      0.001910  0.776508
# Acidity                -0.648451        0.021148     -0.033043  0.724025
# Body                   -0.593066        0.014008     -0.018119  0.697686
# Balance                -0.686870        0.019309      0.048499  0.718161
# Uniformity             -0.331094        0.021577      0.020411  0.366969
# Clean.Cup              -0.309086        0.028315      0.043299  0.335770
# Sweetness              -0.202485        0.007166      0.007361  0.328387
# ...

# %%
Df.plot(kind='scatter',x='Moisture',y='Color')
plt.show()

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit([[1, 2], [np.nan, 3], [7, 6]])
X = [[np.nan, 2], [6, np.nan], [7, 6]]
print(imp.transform(X))
# Out:
# [[4.         2.        ]
#  [6.         3.66666667]
#  [7.         6.        ]]

# %%
DfOfColor=Df['Color']
DfOfColor
# Out:
# 0       2
# 1       2
# 2      -1
# 3       2
# 4       2
#        ..
# 1306    3
# 1307    0
# 1308    2
# 1309    2
# 1310    2
# Name: Color, Length: 1310, dtype: int8

# %%
DfOfMoisture=Df['Moisture']
DfOfMoisture
# Out:
# 0       0.12
# 1       0.12
# 2       0.00
# 3       0.11
# 4       0.12
#         ...
# 1306    0.11
# 1307    0.14
# 1308    0.13
# 1309    0.10
# 1310    0.12
# Name: Moisture, Length: 1310, dtype: float64

# %%
NpArrayDfOfMoisture =DfOfMoisture.to_numpy()
NpArrayDfOfMoisture
# Out:
# array([0.12, 0.12, 0.  , ..., 0.13, 0.1 , 0.12])

# %%
NpArrayDfOfColor=DfOfColor.to_numpy()
NpArrayDfOfColor
# Out:
# array([ 2,  2, -1, ...,  2,  2,  2], dtype=int8)

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(NpArrayDfOfMoisture.reshape(-1, 1))
SimpleImputer()
# Out:
# SimpleImputer()

# %%
print(imp_mean.transform(NpArrayDfOfColor.reshape(-1, 1)))
# Out:
# [[ 2.]
#  [ 2.]
#  [-1.]
#  ...
#  [ 2.]
#  [ 2.]
#  [ 2.]]

# %%
TransformedNpArray=imp_mean.transform(NpArrayDfOfColor.reshape(-1, 1))
dflst=pd.DataFrame(TransformedNpArray, columns = ['Color'])
dflst
# Out:
#       Color
# 0       2.0
# 1       2.0
# 2      -1.0
# 3       2.0
# 4       2.0
# ...     ...
# 1305    3.0
# 1306    0.0
# 1307    2.0
# 1308    2.0
# 1309    2.0
#
# [1310 rows x 1 columns]

# %%
dflst.isnull().sum()
# Out:
# Color    0
# dtype: int64

# %%
Df['Country.of.Origin']=Df['Country.of.Origin'].astype('category').cat.codes

# %%
Df.corr()
# Out:
#                       Unnamed: 0  Country.of.Origin  Number.of.Bags  \
# Unnamed: 0              1.000000           0.150525       -0.069985
# Country.of.Origin       0.150525           1.000000       -0.506859
# Number.of.Bags         -0.069985          -0.506859        1.000000
# Harvest.Year           -0.059588          -0.225876        0.161597
# Aroma                  -0.627560          -0.057198       -0.013084
# Flavor                 -0.731404          -0.074990       -0.008531
# Aftertaste             -0.728466          -0.049299       -0.012212
# Acidity                -0.648451          -0.038791        0.021148
# Body                   -0.593066          -0.046579        0.014008
# Balance                -0.686870          -0.106562        0.019309
# Uniformity             -0.331094          -0.096436        0.021577
# Clean.Cup              -0.309086          -0.051637        0.028315
# Sweetness              -0.202485          -0.018991        0.007166
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
DfOfnumberofbags=Df['Number.of.Bags']
DfOfnumberofbags
# Out:
# 0       300
# 1       300
# 2         5
# 3       320
# 4       300
#        ...
# 1306     12
# 1307      1
# 1308    550
# 1309    275
# 1310    275
# Name: Number.of.Bags, Length: 1310, dtype: int64

# %%
NpArrayDfOfnumberofbags =DfOfnumberofbags.to_numpy()
NpArrayDfOfnumberofbags
# Out:
# array([300, 300,   5, ..., 550, 275, 275])

# %%
data = NpArrayDfOfnumberofbags

# %%
scaler = MinMaxScaler()

# %%
print(scaler.fit(data.reshape(-1,1)))
# Out:
# MinMaxScaler()

# %%
print(scaler.data_max_)
# Out:
# [1062.]

# %%
newnpar1=scaler.transform(data.reshape(-1,1))
newnpar1
# Out:
# array([[0.28248588],
#        [0.28248588],
#        [0.0047081 ],
#        ...,
#        [0.51789077],
#        [0.25894539],
#        [0.25894539]])

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
Df.shape
# Out:
# (1310, 44)

# %%
data=Df[['Country.of.Origin','Acidity','Body','Balance']].values.tolist()

# %%
Oc = Df[Df["Country.of.Origin"].notnull()]
Acidity = Df[Df["Acidity"].notnull()]
Aftertaste = Df[Df["Aftertaste"].notnull()]
İnner = pd.concat([Oc, Acidity], axis=1, join="inner")
İnner2 = pd.concat([İnner, Aftertaste], axis=1, join="inner")
İnner2
# Out:
#       Unnamed: 0  Species                       Owner  Country.of.Origin  \
# 0              1  Arabica                   metad plc                  8
# 1              2  Arabica                   metad plc                  8
# 2              3  Arabica    grounds for health admin                  9
# 3              4  Arabica         yidnekachew dabessa                  8
# 4              5  Arabica                   metad plc                  8
# ...          ...      ...                         ...                ...
# 1306        1307  Arabica    juan carlos garcia lopez                 19
# 1307        1308  Arabica     myriam kaplan-pasternak                 10
# 1308        1309  Arabica  exportadora atlantic, s.a.                 21
# 1309        1310  Arabica   juan luis alvarado romero                  9
# 1310        1312  Arabica             bismarck castro                 11
#
#                                      Farm.Name                  Lot.Number  \
# ...

# %%
minsup = float(input("min sup" ))
minconf=float(input("min conf"))
Df.shape

# %%
a = TransactionEncoder()

# %%
Oc2=list(Oc["Country.of.Origin"].apply(lambda x:x.split(", ")))

Oc2

# %%
Acidtity2=Df["Acidity"]
Aftertaste2=Df["Aftertaste"]
Acidity2["Acidity"] = Acidity2["Acidity"].apply(str) 
Aftertaste2["Aftertaste"] = Df["Aftertaste"].apply(str) 
İnner = pd.concat([Oc2, Acidity2], axis=1, join="inner")
İnner2 = pd.concat([İnner, Aftertaste2], axis=1, join="inner")
İnner2
from mlxtend.preprocessing import TransactionEncoder
a = TransactionEncoder()
a_data = a.fit(Aftertaste).transform(Aftertaste)
a_data
df = pd.DataFrame(a_data,columns=a.columns_)
df = df.replace(False,0)
df
df = apriori(df, min_support = 0.1, use_colnames = True, verbose = 1)
df.sort_values('support', ascending = False)
İnner = pd.concat([Oc2, Acidity2], axis=1, join="inner")
İnner2 = pd.concat([İnner, Aftertaste2], axis=1, join="inner")
İnner2
